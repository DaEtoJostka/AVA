# %%
import math
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator

# %%
# Путь к весам
model = YOLO("../weights/yolov10n.pt")

# Путь к видеофайлу
cap = cv2.VideoCapture("../test_videos/snowboarding.mp4")

# Получение параметров видео: ширина, высота и FPS
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Выходной видеофайл с настройками кодека
out = cv2.VideoWriter("../output_videos/visioneye_distance_calculation_output.mp4", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Параметры вычисления
center_point = (0, h)  # Центр экрана
pixel_per_meter = 10   # Соотношение пикселей на метр

# Цвета для аннотаций
txt_color = (0, 0, 0)  # Цвет текста
txt_background = (255, 255, 255)  # Цвет фона текста
bbox_clr = (255, 0, 255)  # Цвет рамки
# Out:
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
while True:
    ret, im0 = cap.read()
    if not ret:
        print("Кадр видео пустой или обработка видео прошла успешно.")
        break

    # Создаем аннотатор для кадра
    annotator = Annotator(im0, line_width=2)

    # Обрабатываем кадр моделью YOLO
    results = model.track(im0, persist=True)
    boxes = results[0].boxes.xyxy.cpu()

    if results[0].boxes.id is not None:
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            annotator.box_label(box, label=str(track_id), color=bbox_clr)
            annotator.visioneye(box, center_point)

            # Вычисляем центр рамки
            x1, y1 = int((box[0] + box[2]) // 2), int((box[1] + box[3]) // 2)

            # Вычисляем расстояние до точки внизу экрана
            distance = (math.sqrt((x1 - center_point[0]) ** 2 + (y1 - center_point[1]) ** 2)) / pixel_per_meter

            # Добавляем текст расстояния на кадр
            text_size, _ = cv2.getTextSize(f"Distance: {distance:.2f} m", cv2.FONT_HERSHEY_SIMPLEX, 1.2, 3)
            cv2.rectangle(im0, (x1, y1 - text_size[1] - 10), (x1 + text_size[0] + 10, y1), txt_background, -1)
            cv2.putText(im0, f"Distance: {distance:.2f} m", (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 1.2, txt_color, 3)

    # Сохраняем обработанный кадр
    out.write(im0)
    cv2.imshow("Visioneye distance calculation", im0)

    # Выход при нажатии клавиши "q"
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Освобождение ресурсов
out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 person, 148.3ms
# Speed: 2.6ms preprocess, 148.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 143.1ms
# Speed: 2.5ms preprocess, 143.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.7ms
# Speed: 2.0ms preprocess, 187.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.0ms
# Speed: 2.2ms preprocess, 155.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 117.8ms
# Speed: 1.8ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.1ms
# Speed: 6.5ms preprocess, 194.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 113.4ms
# Speed: 2.0ms preprocess, 113.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 222.2ms
# Speed: 3.7ms preprocess, 222.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 119.5ms
# Speed: 1.8ms preprocess, 119.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 117.4ms
# Speed: 2.9ms preprocess, 117.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 125.7ms
# Speed: 1.3ms preprocess, 125.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 119.5ms
# Speed: 1.3ms preprocess, 119.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 297.2ms
# Speed: 1.6ms preprocess, 297.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person,
9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.0ms
# Speed: 1.3ms preprocess, 136.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 109.9ms
# Speed: 1.3ms preprocess, 109.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 snowboard, 129.0ms
# Speed: 1.6ms preprocess, 129.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 107.2ms
# Speed: 1.7ms preprocess, 107.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 124.2ms
# Speed: 1.7ms preprocess, 124.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 snowboard, 136.9ms
# Speed: 2.1ms preprocess, 136.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 140.9ms
# Speed: 2.5ms preprocess, 140.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 259.8ms
# Speed: 1.8ms preprocess, 259.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.1ms
# Speed: 12.4ms preprocess, 186.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 160.4ms
# Speed: 2.3ms preprocess, 160.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 179.8ms
# Speed: 1.5ms preprocess, 179.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 175.9ms
# Speed: 1.7ms preprocess, 175.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 snowboard, 204.9ms
# Speed: 16.2ms preprocess, 204.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 106.5ms
# Speed: 1.6ms preprocess, 106.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 121.4ms
# Speed: 2.2ms preprocess, 121.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 158.8ms
# Speed: 1.9ms preprocess, 158.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 136.7ms
# Speed: 1.6ms preprocess, 136.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 231.3ms
# Speed: 1.5ms preprocess, 231.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 147.6ms
# Speed: 1.7ms preprocess, 147.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 147.8ms
# Speed: 1.6ms preprocess, 147.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 117.9ms
# Speed: 1.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 133.5ms
# Speed: 1.8ms preprocess, 133.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 108.8ms
# Speed: 1.6ms preprocess, 108.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 114.6ms
# Speed: 1.5ms preprocess, 114.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 skis, 125.1ms
# Speed: 2.0ms preprocess, 125.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 114.4ms
# Speed: 1.6ms preprocess, 114.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 109.0ms
# Speed: 1.7ms preprocess, 109.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.2ms
# Speed: 1.4ms preprocess, 157.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 skis, 117.9ms
# Speed: 1.7ms preprocess, 117.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 skis, 142.2ms
# Speed: 1.3ms preprocess, 142.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 skis, 125.3ms
# Speed: 1.5ms preprocess, 125.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 skis, 167.9ms
# Speed: 2.0ms preprocess, 167.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 121.1ms
# Speed: 2.9ms preprocess, 121.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 109.9ms
# Speed: 2.0ms preprocess, 109.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 skis, 119.6ms
# Speed: 1.6ms preprocess, 119.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 119.7ms
# Speed: 1.7ms preprocess, 119.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 105.0ms
# Speed: 1.4ms preprocess, 105.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 100.6ms
# Speed: 1.5ms preprocess, 100.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 117.8ms
# Speed: 1.5ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 152.2ms
# Speed: 2.9ms preprocess, 152.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 126.7ms
# Speed: 1.6ms preprocess, 126.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 snowboard, 181.5ms
# Speed: 1.5ms preprocess, 181.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 219.6ms
# Speed: 2.3ms preprocess, 219.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 128.6ms
# Speed: 1.8ms preprocess, 128.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 115.3ms
# Speed: 1.9ms preprocess, 115.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 snowboard, 118.8ms
# Speed: 1.7ms preprocess, 118.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 104.6ms
# Speed: 1.5ms preprocess, 104.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 snowboard, 117.1ms
# Speed: 1.6ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 snowboard, 118.6ms
# Speed: 1.4ms preprocess, 118.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 109.0ms
# Speed: 1.3ms preprocess, 109.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 119.3ms
# Speed: 1.8ms preprocess, 119.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 121.6ms
# Speed: 1.4ms preprocess, 121.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 115.8ms
# Speed: 1.6ms preprocess, 115.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 kite, 126.1ms
# Speed: 1.6ms preprocess, 126.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 122.5ms
# Speed: 2.1ms preprocess, 122.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 115.9ms
# Speed: 2.0ms preprocess, 115.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 112.9ms
# Speed: 1.6ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 103.7ms
# Speed: 1.4ms preprocess, 103.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 103.9ms
# Speed: 1.3ms preprocess, 103.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 117.0ms
# Speed: 1.4ms preprocess, 117.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 111.7ms
# Speed: 1.4ms preprocess, 111.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 118.0ms
# Speed: 1.7ms preprocess, 118.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 122.4ms
# Speed: 1.4ms preprocess, 122.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 219.2ms
# Speed: 1.4ms preprocess, 219.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 112.8ms
# Speed: 1.6ms preprocess, 112.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 110.7ms
# Speed: 1.6ms preprocess, 110.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 120.3ms
# Speed: 1.4ms preprocess, 120.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 111.1ms
# Speed: 1.4ms preprocess, 111.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 113.4ms
# Speed: 3.1ms preprocess, 113.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 116.4ms
# Speed: 1.6ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 115.1ms
# Speed: 1.6ms preprocess, 115.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 111.3ms
# Speed: 1.7ms preprocess, 111.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 113.3ms
# Speed: 1.4ms preprocess, 113.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 106.6ms
# Speed: 2.5ms preprocess, 106.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 109.9ms
# Speed: 1.7ms preprocess, 109.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 112.5ms
# Speed: 1.4ms preprocess, 112.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 122.2ms
# Speed: 1.5ms preprocess, 122.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 108.7ms
# Speed: 1.6ms preprocess, 108.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 112.3ms
# Speed: 1.5ms preprocess, 112.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 117.0ms
# Speed: 1.5ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 108.9ms
# Speed: 1.7ms preprocess, 108.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.7ms
# Speed: 1.6ms preprocess, 167.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 129.7ms
# Speed: 5.2ms preprocess, 129.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 104.7ms
# Speed: 1.7ms preprocess, 104.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 118.4ms
# Speed: 1.5ms preprocess, 118.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 122.4ms
# Speed: 2.1ms preprocess, 122.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 112.3ms
# Speed: 1.4ms preprocess, 112.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 113.0ms
# Speed: 1.6ms preprocess, 113.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 dog, 242.5ms
# Speed: 1.7ms preprocess, 242.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 115.1ms
# Speed: 1.7ms preprocess, 115.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 117.1ms
# Speed: 1.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 132.2ms
# Speed: 1.6ms preprocess, 132.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 114.6ms
# Speed: 1.5ms preprocess, 114.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 105.0ms
# Speed: 1.5ms preprocess, 105.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 109.1ms
# Speed: 1.6ms preprocess, 109.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 163.1ms
# Speed: 2.4ms preprocess, 163.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 147.9ms
# Speed: 4.8ms preprocess, 147.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 110.1ms
# Speed: 1.9ms preprocess, 110.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 711.2ms
# Speed: 1.9ms preprocess, 711.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 314.1ms
# Speed: 3.6ms preprocess, 314.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# Кадр видео пустой или обработка видео прошла успешно.
